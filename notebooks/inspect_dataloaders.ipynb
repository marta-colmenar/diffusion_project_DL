# %%
from data import load_dataset_and_make_dataloaders

# %% [markdown]
# Let's inspect FashionMNIST..

# %%
dataloader, info = load_dataset_and_make_dataloaders(
    dataset_name="FashionMNIST",
    root_dir="./../data",
    batch_size=16,
    num_workers=1,
    pin_memory=False,
)
data_iter = iter(dataloader.train)
imgs, labels = next(data_iter)

# %%
imgs.shape

# %%
labels

# %% [markdown]
# Ok, now it's the turn of CelebA..

# %%
dataloader, info = load_dataset_and_make_dataloaders(
    dataset_name="CelebA",
    root_dir="./../data",
    batch_size=16,
    num_workers=4,
    pin_memory=False,
)
data_iter = iter(dataloader.train)
imgs, labels = next(data_iter)

# %%
imgs.shape

# %%
labels
